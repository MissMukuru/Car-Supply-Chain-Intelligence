# %% [markdown]
# CAR SUPPLY CHAIN MANAGEMENT EXPLORATORY ANALYSIS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

Chain = pd.read_csv('Car_data.csv')
#print(Chain.head())

chain_df = pd.DataFrame(Chain)
chain_df[0:5]
# Out:
#    SupplierID         SupplierAddress SupplierName SupplierContactDetails  \
# 0           1       542 Dayton Center   Bubbletube            871-57-6028
# 1           2  0674 Springview Circle      Tagopia            337-64-4060
# 2           3   70 Autumn Leaf Center      Zoomdog            218-19-1802
# 3           4         649 Corben Lane         Oozz            635-15-3112
# 4           5      94 Namekagon Point         Kare            849-23-6788
#
#   ProductID    CarMaker     CarModel   CarColor  CarModelYear   CarPrice  ...  \
# 0      8893       Dodge     Ram 2500  Goldenrod          2007  521963.45  ...
# 1      9444      Toyota       Tundra    Crimson          2010  672222.04  ...
# 2       253         GMC  Savana 1500    Crimson          2011  504465.72  ...
# 3      1283  Volkswagen    Cabriolet     Fuscia          1990  646077.11  ...
# 4      8905     Mercury      Mariner       Teal          2009  699890.24  ...
#
# ...

# %%
print(Chain.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SupplierID              1004 non-null   int64
#  1   SupplierAddress         1004 non-null   object
#  2   SupplierName            1004 non-null   object
#  3   SupplierContactDetails  1004 non-null   object
#  4   ProductID               1004 non-null   object
#  5   CarMaker                1004 non-null   object
#  6   CarModel                1004 non-null   object
#  7   CarColor                1004 non-null   object
#  8   CarModelYear            1004 non-null   int64
#  9   CarPrice                1004 non-null   object
#  10  CustomerID              1004 non-null   object
#  11  CustomerName            1004 non-null   object
#  12  Gender                  1004 non-null   object
#  13  JobTitle                1004 non-null   object
# ...

# %%
print("Descriptive abnalysis of price")
Chain_stats = Chain.describe(include = 'all')
print(Chain_stats)
# Out:
# Descriptive abnalysis of price
#          SupplierID         SupplierAddress SupplierName  \
# count   1004.000000                    1004         1004
# unique          NaN                    1000          362
# top             NaN  44379 Anderson Parkway         Kazu
# freq            NaN                       2            8
# mean     502.292829                     NaN          NaN
# std      289.634878                     NaN          NaN
# min        1.000000                     NaN          NaN
# 25%      251.750000                     NaN          NaN
# 50%      502.500000                     NaN          NaN
# 75%      753.250000                     NaN          NaN
# max     1000.000000                     NaN          NaN
#
#        SupplierContactDetails ProductID   CarMaker CarModel CarColor  \
# count                    1004      1004       1004     1004     1004
# unique                   1000       883         55      505       20
# ...

# %%
#Descriptive Analysis of the sales
Chain_stats = Chain['Sales'].describe()
print(Chain_stats)
# Out:
# count      1004.000000
# mean     851431.158974
# std       96299.566882
# min           4.000000
# 25%      775490.077500
# 50%      858073.060000
# 75%      932854.565000
# max      999315.690000
# Name: Sales, dtype: float64

# %%
print("The mean of the sales is: ")
Sales  = Chain['Sales'].mean()
print(Sales)

print("The max value of the sales is")
Sales = Chain['Sales'].max()
print(Sales)

print("The Counts of the Sales are: ")
Sales = Chain["Sales"].count()
print(Sales)
# Out:
# The mean of the sales is:
# 851431.1589741036
# The max value of the sales is
# 999315.69
# The Counts of the Sales are:
# 1004

# %%
print("The mean of the CarPrice is: ")
CarPrice = Chain['CarPrice'].mean()
print(CarPrice)

print("The max value of the CarPrice is")
CarPrice = Chain['CarPrice'].max()
print(CarPrice)

print("The Counts of the Sales are: ")
CarPrice = Chain['CarPrice'].count()
print(CarPrice)
# Out:
# The mean of the CarPrice is:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 print("The mean of the CarPrice is: ")
# ----> 2 CarPrice = Chain['CarPrice'].mean()
#       3 print(CarPrice)
#       5 print("The max value of the CarPrice is")
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
# ...

# %% [markdown]
# USING NUMPY TO PERFORM BETTER EXPLOARATORY ANALYSIS

# %%
import pandas as pd
import numpy as np

Chain = pd.read_csv('Car_data.csv')
column_to_convert = 'Sales'
sales_array = Chain[column_to_convert].values

print(sales_array)
print(sales_array.dtype)
# Out:
# [744796.41 794773.17 968244.9  ... 894256.15 704141.33 946497.71]
# float64

# %%
import numpy as np
Chain = pd.read_csv('Car_data.csv')
column_to_convert = 'Sales'
sales_array = Chain[column_to_convert].values
print(sales_array)
total_sales = np.sum(sales_array)
print(total_sales)
# Out:
# [744796.41 794773.17 968244.9  ... 894256.15 704141.33 946497.71]
# 854836883.61

# %%
#Multiplying the sales data by the discount and adding the results

import numpy as np
import pandas as pd
Chain = pd.read_csv('Car_data.csv')
column_to_convert = 'Sales'
col_to_convert = 'Discount'
sales_array = Chain[column_to_convert].values
Discount_array = Chain[col_to_convert].values

print(sales_array)
print(Discount_array)

Discounted_price = np.multiply(sales_array, Discount_array)
print(Discount_array)

new_sales = np.prod(Discounted_price)
print(new_sales)
# Out:
# [744796.41 794773.17 968244.9  ... 894256.15 704141.33 946497.71]
# [0.83 0.79 0.28 ... 0.57 0.3  0.86]
# [0.83 0.79 0.28 ... 0.57 0.3  0.86]
# inf
# c:\Program Files\Python312\Lib\site-packages\numpy\core\fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %% [markdown]
# STATISTICAL EVALUATION OF DATA

# %%
import pandas as pd
from numpy import random
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image

sales_array = random.normal(loc = 851431.158974, scale = 96299.566882 , size = (2,3))
print(sales_array)

sns.distplot(random.normal(size = 1000),hist = False)
plt.show()
# Out:
# [[858501.80128632 817653.10113305 790734.39988639]
#  [824100.40453895 915170.80525907 807399.31883447]]
# C:\Users\HPPC\AppData\Local\Temp\ipykernel_8656\3605598768.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size = 1000),hist = False)

# %%
#Choosing the columns im supposed to use
chain_set = chain_df[['SupplierID','SupplierAddress','SupplierName','SupplierContactDetails', 'ProductID' ,'CarMaker','CarModel','CarColor','CarModelYear','CarPrice','CustomerID','CustomerName','Gender','JobTitle','EmailAddress','City','Country','State','CustomerAddress','OrderID','Sales','Quantity','Discount','CustomerFeedback']]
chain_set.head(10)
# Out:
#    SupplierID         SupplierAddress SupplierName SupplierContactDetails  \
# 0           1       542 Dayton Center   Bubbletube            871-57-6028
# 1           2  0674 Springview Circle      Tagopia            337-64-4060
# 2           3   70 Autumn Leaf Center      Zoomdog            218-19-1802
# 3           4         649 Corben Lane         Oozz            635-15-3112
# 4           5      94 Namekagon Point         Kare            849-23-6788
# 5           6     46347 Dunning Drive       Rhynyx            378-57-0118
# 6           7      85 Coleman Parkway       Roombo            479-97-2408
# 7           8  30230 Westerfield Pass      Wordify            371-69-6870
# 8           9        4 Coleman Street        Skyvu            717-19-7839
# 9          10        100 Anhalt Place     Feedfire            634-55-4653
#
#   ProductID    CarMaker      CarModel   CarColor  CarModelYear   CarPrice  \
# 0      8893       Dodge      Ram 2500  Goldenrod          2007  521963.45
# ...

# %%
chain_set['CarPrice']= pd.to_numeric(chain_set['CarPrice'], errors = 'coerce')
chain_set['CarPrice'] = np.log(chain_set['CarPrice'] + 1 )
chain_sample = chain_set.sample(frac = 0.1, random_state=42)
plt.scatter(chain_sample.CarModelYear, chain_sample.CarPrice, color = 'Pink')
plt.xlabel('car model year')
plt.ylabel('Carprice')
plt.title('Realation between car price and car year')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: can only concatenate str (not "int") to str
#
# ...
